# %%
radius= int( input("enter value of radius:"))
pi=3.142
area=pi*(radius*radius)
print(f"the area with radius {radius} is:{area}")
# Out:
# enter value of radius: 3
# the area with radius 3 is:28.278
