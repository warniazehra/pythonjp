# %%
num1= int(input("enter first num:"))
num2= int(input("enter second num:"))
sum=num1 + num2
print("the sum of num1 and num2 is sum",num1, num2, sum)
# Out:
# enter first num: 3
# enter second num: 5
# the sum of num1 and num2 is sum 3 5 8
